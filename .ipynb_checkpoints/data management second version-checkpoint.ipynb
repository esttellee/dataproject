# %%
from bs4 import BeautifulSoup
import requests
from pprint import pprint
from urllib.request import Request, urlopen

url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# # Scraping des infos du top 250

# %%
titles = soup.find_all('td', class_='titleColumn')

# %% [markdown]
# essayer de ne faire apparaître que les acteurs présents dans la liste de allociné

# %%
#récupere la liste des acteurs connus
list_actors_famous = []
for page in range(1, 21):
    url_actor_star = f'https://www.allocine.fr/personne/top/les-plus-vues/ever/?page={page}'
#le f sert à formater l'URL
    response_actor = requests.get(url_actor_star)
    actor_soup = BeautifulSoup(response_actor.content, 'html.parser')
    actors_famous = actor_soup.find_all('a', class_= "meta-title-link")
    
#mettre tous les acteurs scrapper dans une liste   
    for actor in actors_famous:
        actor_star = actor.text.strip()
        list_actors_famous.append(actor_star)

# %%
for title in titles:
    movie_title = title.a.text
    movie_year = title.span.text.strip('()')
    ratings = title.find_next_sibling('td', class_= 'ratingColumn')
    
 #aller scrapper sur les pages de chaque film
    movie_url = 'https://www.imdb.com' + title.a['href']
    req = Request(
    url=movie_url, 
    headers={'User-Agent': 'Mozilla/5.0'}
    )
    
    movie_response = urlopen(req).read()
    movie_soup = BeautifulSoup(movie_response, 'html.parser')
    genre_span = movie_soup.find('span', {'class': 'ipc-chip__text'}).text.strip()
        
    director_movie = movie_soup.find('a', class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link").text.strip()
    
    actors_list = movie_soup.find_all("a", class_="sc-bfec09a1-1 fUguci")
    #créer une liste pour les acteurs en commun avec allociné
    actors_common = []   
    #essayer de n'afficher que les acteurs célèbres
    for actor in actors_list:
        actor_name = actor.text.strip()
        if actor_name in list_actors_famous:
            actors_common.append(actor_name)

    
    movie_dict = {
        'title': movie_title,
        'year': movie_year,
        'rating': float(ratings.text),
        'genre':genre_span,
        'director': director_movie,
        'actor': actors_common
    }
 
    print(movie_dict)
# Out:
# {'title': 'The Shawshank Redemption', 'year': '1994', 'rating': 9.2, 'genre': 'Drama', 'director': 'Frank Darabont', 'actor': ['Morgan Freeman']}
# {'title': 'The Godfather', 'year': '1972', 'rating': 9.2, 'genre': 'Crime', 'director': 'Francis Ford Coppola', 'actor': ['Al Pacino']}
# {'title': 'The Dark Knight', 'year': '2008', 'rating': 9.0, 'genre': 'Action', 'director': 'Christopher Nolan', 'actor': ['Christian Bale', 'Gary Oldman', 'Morgan Freeman', 'Cillian Murphy']}
# {'title': 'The Godfather Part II', 'year': '1974', 'rating': 9.0, 'genre': 'Crime', 'director': 'Francis Ford Coppola', 'actor': ['Al Pacino', 'Robert De Niro']}
# {'title': '12 Angry Men', 'year': '1957', 'rating': 9.0, 'genre': 'Crime', 'director': 'Sidney Lumet', 'actor': []}
# {'title': "Schindler's List", 'year': '1993', 'rating': 8.9, 'genre': 'Biography', 'director': 'Steven Spielberg', 'actor': ['Liam Neeson', 'Ralph Fiennes']}
# {'title': 'The Lord of the Rings: The Return of the King', 'year': '2003', 'rating': 8.9, 'genre': 'Action', 'director': 'Peter Jackson', 'actor': ['Viggo Mortensen', 'Cate Blanchett']}
# {'title': 'Pulp Fiction', 'year': '1994', 'rating': 8.8, 'genre': 'Crime', 'director': 'Quentin Tarantino', 'actor': ['Samuel L. Jackson', 'Bruce Willis']}
# {'title': 'The Lord of the Rings: The Fellowship of the Ring', 'year': '2001', 'rating': 8.8, 'genre': 'Action', 'director': 'Peter Jackson', 'actor': ['Viggo Mortensen', 'Cate Blanchett']}
# {'title': 'Il buono, il brutto, il cattivo', 'year': '1966', 'rating': 8.8, 'genre': 'Adventure', 'director': 'Sergio Leone', 'actor': ['Clint Eastwood']}
# {'title': 'Forrest Gump', 'year': '1994', 'rating': 8.8, 'genre': 'Drama', 'director': 'Robert Zemeckis', 'actor': ['Tom Hanks']}
# {'title': 'Fight Club', 'year': '1999', 'rating': 8.7, 'genre': 'Drama', 'director': 'David Fincher', 'actor': ['Brad Pitt', 'Edward Norton', 'Helena Bonham Carter']}
# {'title': 'The Lord of the Rings: The Two Towers', 'year': '2002', 'rating': 8.7, 'genre': 'Action', 'director': 'Peter Jackson', 'actor': ['Viggo Mortensen', 'Cate Blanchett']}
# {'title': 'Inception', 'year': '2010', 'rating': 8.7, 'genre': 'Action', 'director': 'Christopher Nolan', 'actor': ['Leonardo DiCaprio', 'Elliot Page', 'Tom Hardy', 'Cillian Murphy', 'Marion Cotillard']}
# {'title': 'The Empire Strikes Back', 'year': '1980', 'rating': 8.7, 'genre': 'Action', 'director': 'Irvin Kershner', 'actor': ['Harrison Ford']}
# {'title': 'The Matrix', 'year': '1999', 'rating': 8.7, 'genre': 'Action', 'director': 'Lana Wachowski', 'actor': ['Keanu Reeves']}
# {'title': 'GoodFellas', 'year': '1990', 'rating': 8.7, 'genre': 'Biography', 'director': 'Martin Scorsese', 'actor': ['Robert De Niro']}
# {'title': "One Flew Over the Cuckoo's Nest", 'year': '1975', 'rating': 8.6, 'genre': 'Drama', 'director': 'Milos Forman', 'actor': ['Jack Nicholson']}
# {'title': 'Se7en', 'year': '1995', 'rating': 8.6, 'genre': 'Crime', 'director': 'David Fincher', 'actor': ['Morgan Freeman', 'Brad Pitt']}
# {'title': "It's a Wonderful Life", 'year': '1946', 'rating': 8.6, 'genre': 'Drama', 'director': 'Frank Capra', 'actor': []}
# {'title': 'Shichinin no samurai', 'year': '1954', 'rating': 8.6, 'genre': 'Action', 'director': 'Akira Kurosawa', 'actor': []}
# {'title': 'The Silence of the Lambs', 'year': '1991', 'rating': 8.6, 'genre': 'Crime', 'director': 'Jonathan Demme', 'actor': ['Anthony Hopkins']}
# {'title': 'Saving Private Ryan', 'year': '1998', 'rating': 8.6, 'genre': 'Drama', 'director': 'Steven Spielberg', 'actor': ['Tom Hanks', 'Matt Damon', 'Vin Diesel']}
# {'title': 'Cidade de Deus', 'year': '2002', 'rating': 8.6, 'genre': 'Crime', 'director': 'Fernando Meirelles', 'actor': []}
# {'title': 'Interstellar', 'year': '2014', 'rating': 8.6, 'genre': 'Adventure', 'director': 'Christopher Nolan', 'actor': ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain', 'Timothée Chalamet']}
# {'title': 'La vita è bella', 'year': '1997', 'rating': 8.6, 'genre': 'Comedy', 'director': 'Roberto Benigni', 'actor': []}
# {'title': 'The Green Mile', 'year': '1999', 'rating': 8.6, 'genre': 'Crime', 'director': 'Frank Darabont', 'actor': ['Tom Hanks']}
# {'title': 'Star Wars', 'year': '1977', 'rating': 8.5, 'genre': 'Action', 'director': 'George Lucas', 'actor': ['Harrison Ford']}
# {'title': 'Terminator 2: Judgment Day', 'year': '1991', 'rating': 8.5, 'genre': 'Action', 'director': 'James Cameron', 'actor': ['Arnold Schwarzenegger']}
# {'title': 'Back to the Future', 'year': '1985', 'rating': 8.5, 'genre': 'Adventure', 'director': 'Robert Zemeckis', 'actor': []}
# {'title': 'Sen to Chihiro no kamikakushi', 'year': '2001', 'rating': 8.5, 'genre': 'Animation', 'director': 'Hayao Miyazaki', 'actor': []}
# {'title': 'The Pianist', 'year': '2002', 'rating': 8.5, 'genre': 'Biography', 'director': 'Roman Polanski', 'actor': []}
# {'title': 'Psycho', 'year': '1960', 'rating': 8.5, 'genre': 'Horror', 'director': 'Alfred Hitchcock', 'actor': []}
# {'title': 'Gisaengchung', 'year': '2019', 'rating': 8.5, 'genre': 'Drama', 'director': 'Bong Joon Ho', 'actor': []}
# {'title': 'Léon', 'year': '1994', 'rating': 8.5, 'genre': 'Action', 'director': 'Luc Besson', 'actor': ['Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Maïwenn']}
# {'title': 'The Lion King', 'year': '1994', 'rating': 8.5, 'genre': 'Animation', 'director': 'Roger Allers', 'actor': []}
# {'title': 'Gladiator', 'year': '2000', 'rating': 8.5, 'genre': 'Action', 'director': 'Ridley Scott', 'actor': ['Russell Crowe', 'Joaquin Phoenix']}
# {'title': 'American History X', 'year': '1998', 'rating': 8.5, 'genre': 'Crime', 'director': 'Tony Kaye', 'actor': ['Edward Norton']}
# {'title': 'The Departed', 'year': '2006', 'rating': 8.5, 'genre': 'Crime', 'director': 'Martin Scorsese', 'actor': ['Leonardo DiCaprio', 'Matt Damon', 'Jack Nicholson', 'Mark Wahlberg']}
# {'title': 'Whiplash', 'year': '2014', 'rating': 8.5, 'genre': 'Drama', 'director': 'Damien Chazelle', 'actor': ['Miles Teller']}
# {'title': 'The Prestige', 'year': '2006', 'rating': 8.5, 'genre': 'Drama', 'director': 'Christopher Nolan', 'actor': ['Christian Bale', 'Hugh Jackman', 'Scarlett Johansson']}
# {'title': 'The Usual Suspects', 'year': '1995', 'rating': 8.5, 'genre': 'Crime', 'director': 'Bryan Singer', 'actor': []}
# {'title': 'Casablanca', 'year': '1942', 'rating': 8.5, 'genre': 'Drama', 'director': 'Michael Curtiz', 'actor': []}
# {'title': 'Hotaru no haka', 'year': '1988', 'rating': 8.5, 'genre': 'Animation', 'director': 'Isao Takahata', 'actor': []}
# {'title': 'Seppuku', 'year': '1962', 'rating': 8.5, 'genre': 'Action', 'director': 'Masaki Kobayashi', 'actor': []}
# {'title': 'The Intouchables', 'year': '2011', 'rating': 8.5, 'genre': 'Biography', 'director': 'Olivier Nakache', 'actor': ['François Cluzet', 'Omar Sy', 'Audrey Fleurot']}
# {'title': 'Modern Times', 'year': '1936', 'rating': 8.4, 'genre': 'Comedy', 'director': 'Charles Chaplin', 'actor': []}
# {'title': 'Once Upon a Time in the West', 'year': '1968', 'rating': 8.4, 'genre': 'Western', 'director': 'Sergio Leone', 'actor': []}
# {'title': 'Cinema Paradiso', 'year': '1988', 'rating': 8.4, 'genre': 'Drama', 'director': 'Giuseppe Tornatore', 'actor': []}
# {'title': 'Rear Window', 'year': '1954', 'rating': 8.4, 'genre': 'Mystery', 'director': 'Alfred Hitchcock', 'actor': []}
# {'title': 'Alien', 'year': '1979', 'rating': 8.4, 'genre': 'Horror', 'director': 'Ridley Scott', 'actor': []}
# {'title': 'City Lights', 'year': '1931', 'rating': 8.4, 'genre': 'Comedy', 'director': 'Charles Chaplin', 'actor': []}
# {'title': 'Apocalypse Now', 'year': '1979', 'rating': 8.4, 'genre': 'Drama', 'director': 'Francis Ford Coppola', 'actor': ['Harrison Ford']}
# {'title': 'Memento', 'year': '2000', 'rating': 8.4, 'genre': 'Mystery', 'director': 'Christopher Nolan', 'actor': []}
# {'title': 'Django Unchained', 'year': '2012', 'rating': 8.4, 'genre': 'Drama', 'director': 'Quentin Tarantino', 'actor': ['Christoph Waltz', 'Leonardo DiCaprio', 'Samuel L. Jackson']}
# {'title': 'Raiders of the Lost Ark', 'year': '1981', 'rating': 8.4, 'genre': 'Action', 'director': 'Steven Spielberg', 'actor': ['Harrison Ford']}
# {'title': 'WALL·E', 'year': '2008', 'rating': 8.4, 'genre': 'Animation', 'director': 'Andrew Stanton', 'actor': []}
# {'title': 'The Lives of Others', 'year': '2006', 'rating': 8.4, 'genre': 'Drama', 'director': 'Florian Henckel von Donnersmarck', 'actor': []}
# {'title': 'Sunset Blvd.', 'year': '1950', 'rating': 8.4, 'genre': 'Drama', 'director': 'Billy Wilder', 'actor': []}
# {'title': 'Paths of Glory', 'year': '1957', 'rating': 8.4, 'genre': 'Drama', 'director': 'Stanley Kubrick', 'actor': []}
# {'title': 'The Shining', 'year': '1980', 'rating': 8.4, 'genre': 'Drama', 'director': 'Stanley Kubrick', 'actor': ['Jack Nicholson']}
# {'title': 'The Great Dictator', 'year': '1940', 'rating': 8.4, 'genre': 'Comedy', 'director': 'Charles Chaplin', 'actor': []}
# {'title': 'Avengers: Infinity War', 'year': '2018', 'rating': 8.4, 'genre': 'Action', 'director': 'Anthony Russo', 'actor': ['Robert Downey Jr.', 'Chris Hemsworth', 'Chris Evans', 'Scarlett Johansson', 'Benedict Cumberbatch', 'Tom Holland', 'Chadwick Boseman', 'Zoe Saldana', 'Karen Gillan', 'Tom Hiddleston', 'Elizabeth Olsen', 'Idris Elba']}
# {'title': 'Witness for the Prosecution', 'year': '1957', 'rating': 8.4, 'genre': 'Crime', 'director': 'Billy Wilder', 'actor': []}
# {'title': 'Aliens', 'year': '1986', 'rating': 8.3, 'genre': 'Action', 'director': 'James Cameron', 'actor': []}
# {'title': 'Spider-Man: Into the Spider-Verse', 'year': '2018', 'rating': 8.3, 'genre': 'Animation', 'director': 'Bob Persichetti', 'actor': ['Mahershala Ali', 'Nicolas Cage', 'Chris Pine', 'Oscar Isaac']}
# {'title': 'American Beauty', 'year': '1999', 'rating': 8.3, 'genre': 'Drama', 'director': 'Sam Mendes', 'actor': []}
# {'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'year': '1964', 'rating': 8.3, 'genre': 'Comedy', 'director': 'Stanley Kubrick', 'actor': []}
# {'title': 'The Dark Knight Rises', 'year': '2012', 'rating': 8.3, 'genre': 'Action', 'director': 'Christopher Nolan', 'actor': ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman', 'Marion Cotillard', 'Morgan Freeman']}
# {'title': 'Oldeuboi', 'year': '2003', 'rating': 8.3, 'genre': 'Action', 'director': 'Park Chan-wook', 'actor': []}
# {'title': 'Inglourious Basterds', 'year': '2009', 'rating': 8.3, 'genre': 'Adventure', 'director': 'Quentin Tarantino', 'actor': ['Brad Pitt', 'Mélanie Laurent', 'Christoph Waltz', 'Michael Fassbender']}
# {'title': 'Amadeus', 'year': '1984', 'rating': 8.3, 'genre': 'Biography', 'director': 'Milos Forman', 'actor': []}
# {'title': 'Coco', 'year': '2017', 'rating': 8.3, 'genre': 'Animation', 'director': 'Lee Unkrich', 'actor': []}
# {'title': 'Toy Story', 'year': '1995', 'rating': 8.3, 'genre': 'Animation', 'director': 'John Lasseter', 'actor': ['Tom Hanks']}
# {'title': 'Braveheart', 'year': '1995', 'rating': 8.3, 'genre': 'Biography', 'director': 'Mel Gibson', 'actor': ['Mel Gibson', 'Sophie Marceau']}
# {'title': 'Joker', 'year': '2019', 'rating': 8.3, 'genre': 'Crime', 'director': 'Todd Phillips', 'actor': ['Joaquin Phoenix', 'Robert De Niro']}
# {'title': 'Das Boot', 'year': '1981', 'rating': 8.3, 'genre': 'Drama', 'director': 'Wolfgang Petersen', 'actor': []}
# {'title': 'Avengers: Endgame', 'year': '2019', 'rating': 8.3, 'genre': 'Action', 'director': 'Anthony Russo', 'actor': ['Robert Downey Jr.', 'Chris Evans', 'Chris Hemsworth', 'Scarlett Johansson', 'Jeremy Renner', 'Benedict Cumberbatch', 'Chadwick Boseman', 'Brie Larson', 'Tom Holland', 'Karen Gillan', 'Zoe Saldana', 'Tessa Thompson', 'Elizabeth Olsen']}
# {'title': 'Mononoke-hime', 'year': '1997', 'rating': 8.3, 'genre': 'Animation', 'director': 'Hayao Miyazaki', 'actor': []}
# {'title': 'Once Upon a Time in America', 'year': '1984', 'rating': 8.3, 'genre': 'Crime', 'director': 'Sergio Leone', 'actor': ['Robert De Niro']}
# {'title': 'Good Will Hunting', 'year': '1997', 'rating': 8.3, 'genre': 'Drama', 'director': 'Gus Van Sant', 'actor': ['Robin Williams', 'Matt Damon', 'Ben Affleck']}
# {'title': 'Kimi no na wa.', 'year': '2016', 'rating': 8.3, 'genre': 'Animation', 'director': 'Makoto Shinkai', 'actor': []}
# {'title': "Singin' in the Rain", 'year': '1952', 'rating': 8.3, 'genre': 'Comedy', 'director': 'Stanley Donen', 'actor': []}
# {'title': '3 Idiots', 'year': '2009', 'rating': 8.3, 'genre': 'Comedy', 'director': 'Rajkumar Hirani', 'actor': []}
# {'title': 'Requiem for a Dream', 'year': '2000', 'rating': 8.3, 'genre': 'Drama', 'director': 'Darren Aronofsky', 'actor': ['Jared Leto', 'Jennifer Connelly']}
# {'title': 'Tengoku to jigoku', 'year': '1963', 'rating': 8.3, 'genre': 'Crime', 'director': 'Akira Kurosawa', 'actor': []}
# {'title': 'Toy Story 3', 'year': '2010', 'rating': 8.3, 'genre': 'Animation', 'director': 'Lee Unkrich', 'actor': ['Tom Hanks']}
# {'title': 'Capharnaüm', 'year': '2018', 'rating': 8.3, 'genre': 'Drama', 'director': 'Nadine Labaki', 'actor': []}
# {'title': 'Star Wars: Episode VI - Return of the Jedi', 'year': '1983', 'rating': 8.3, 'genre': 'Action', 'director': 'Richard Marquand', 'actor': ['Harrison Ford']}
# {'title': '2001: A Space Odyssey', 'year': '1968', 'rating': 8.3, 'genre': 'Adventure', 'director': 'Stanley Kubrick', 'actor': []}
# {'title': 'Eternal Sunshine of the Spotless Mind', 'year': '2004', 'rating': 8.3, 'genre': 'Drama', 'director': 'Michel Gondry', 'actor': ['Jim Carrey', 'Kate Winslet']}
# {'title': 'Idi i smotri', 'year': '1985', 'rating': 8.3, 'genre': 'Drama', 'director': 'Elem Klimov', 'actor': []}
# {'title': 'Reservoir Dogs', 'year': '1992', 'rating': 8.3, 'genre': 'Crime', 'director': 'Quentin Tarantino', 'actor': ['Quentin Tarantino']}
# {'title': 'Jagten', 'year': '2012', 'rating': 8.3, 'genre': 'Drama', 'director': 'Thomas Vinterberg', 'actor': ['Mads Mikkelsen']}
# {'title': 'Citizen Kane', 'year': '1941', 'rating': 8.2, 'genre': 'Drama', 'director': 'Orson Welles', 'actor': []}
# {'title': 'Lawrence of Arabia', 'year': '1962', 'rating': 8.2, 'genre': 'Adventure', 'director': 'David Lean', 'actor': []}
# {'title': 'M - Eine Stadt sucht einen Mörder', 'year': '1931', 'rating': 8.2, 'genre': 'Crime', 'director': 'Fritz Lang', 'actor': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#       7 movie_url = 'https://www.imdb.com' + title.a['href']
#       8 req = Request(
#       9 url=movie_url,
#      10 headers={'User-Agent': 'Mozilla/5.0'}
#      11 )
# ---> 13 movie_response = urlopen(req).read()
#      14 movie_soup = BeautifulSoup(movie_response, 'html.parser')
#      15 genre_span = movie_soup.find('span', {'class': 'ipc-chip__text'}).text.strip()
#
# File ~\anaconda3\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\anaconda3\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\anaconda3\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\anaconda3\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File ~\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # visualisation test

# %%
import matplotlib.pyplot as plt

# Création d'une liste de titres de films et de leurs notes
titles = [movie['title'] for movie in movie_dict]
ratings = [movie['rating'] for movie in movie_dict]

# Création d'un graphique en barres horizontales pour les notes des films
plt.barh(titles, ratings)
plt.xlabel('Note')
plt.ylabel('Titre du film')
plt.title('Notes des films')
plt.show()

# Création d'un graphique en camembert pour les genres de films
genres = {}
for movie in movie_dict:
    genre = movie['genre']
    if genre in genres:
        genres[genre] += 1
    else:
        genres[genre] = 1

genre_labels = list(genres.keys())
genre_counts = list(genres.values())

plt.pie(genre_counts, labels=genre_labels, autopct='%1.1f%%')
plt.title('Genres de films')
plt.show()

# Création d'un graphique à barres pour les réalisateurs de films
directors = {}
for movie in movie_dict:
    director = movie['director']
    if director in directors:
        directors[director] += 1
    else:
        directors[director] = 1

director_labels = list(directors.keys())
director_counts = list(directors.values())

plt.bar(director_labels, director_counts)
plt.xlabel('Réalisateur')
plt.ylabel('Nombre de films')
plt.title('Réalisateurs de films')
plt.xticks(rotation=90)
plt.show()

# Création d'un graphique en nuage de points pour les acteurs communs avec Allociné
actors = {}
for movie in movie_dict:
    for actor in movie['actor']:
        if actor in actors:
            actors[actor] += 1
        else:
            actors[actor] = 1

actor_labels = list(actors.keys())
actor_counts = list(actors.values())

plt.scatter(actor_labels, actor_counts)
plt.xlabel('Acteur')
plt.ylabel('Nombre de films')
plt.title('Acteurs communs avec Allociné')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Création d'une liste de titres de films et de leurs notes
# ----> 4 titles = [movie['title'] for movie in movie_dict]
#       5 ratings = [movie['rating'] for movie in movie_dict]
#       7 # Création d'un graphique en barres horizontales pour les notes des films
#
# Cell In[6], line 4, in <listcomp>(.0)
#       1 import matplotlib.pyplot as plt
#       3 # Création d'une liste de titres de films et de leurs notes
# ----> 4 titles = [movie['title'] for movie in movie_dict]
#       5 ratings = [movie['rating'] for movie in movie_dict]
#       7 # Création d'un graphique en barres horizontales pour les notes des films
#
# TypeError: string indices must be integers

# %% [markdown]
# # scraper les infos des films dans la section "prochaine apparution IMBD"

# %%
url_sortie = "https://www.imdb.com/calendar/?ref_=rlm&region=BE&type=MOVIE"
req = Request(
url= url_sortie, 
headers={'User-Agent': 'Mozilla/5.0'}
)
    
response_sortie = urlopen(req).read()
sortie_soup = BeautifulSoup(response_sortie, 'html.parser')

# %%
movie_sortie = sortie_soup.find_all('div', class_= "ipc-metadata-list-summary-item__c")

# %%
for movie in movie_sortie:
    sortie_title = movie.find('a', class_= "ipc-metadata-list-summary-item__t").text.strip()
    
    movie_sortie_url = 'https://www.imdb.com' + movie.a['href']
    req = Request(
    url=movie_sortie_url, 
    headers={'User-Agent': 'Mozilla/5.0'}
    )
    
    movie_sortie_response = urlopen(req).read()
    sortie_soup = BeautifulSoup(movie_sortie_response, 'html.parser')
    genre_sortie = sortie_soup.find('span', {'class': 'ipc-chip__text'}).text.strip()
    director_sortie = sortie_soup.find('a', class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link").text.strip()
    
    actors_sortie_list = sortie_soup.find_all("a", class_="sc-bfec09a1-1 fUguci")
    actors_common_sortie = []   
    #essayer de n'afficher que les acteurs célèbres
    for actor in actors_sortie_list:
        actor_name_sortie = actor.text.strip()
        if actor_name_sortie in list_actors_famous:
            actors_common_sortie.append(actor_name_sortie)
   
    
    movie_sortie = {
        'title': sortie_title,
        'genre':genre_sortie,
        'director': director_sortie,
        'actor': actors_common_sortie
    }
 
    print(movie_sortie)
# Out:
# {'title': 'Guardians of the Galaxy Vol. 3 (2023)', 'genre': 'Action', 'director': 'James Gunn', 'actor': ['Chris Pratt', 'Zoe Saldana', 'Vin Diesel', 'Bradley Cooper', 'Karen Gillan', 'Sylvester Stallone']}
# {'title': 'Alice, Darling (2022)', 'genre': 'Drama', 'director': 'Mary Nighy', 'actor': ['Anna Kendrick']}
# {'title': 'Savage Salvation (2022)', 'genre': 'Action', 'director': 'Randall Emmett', 'actor': ['Robert De Niro']}
# {'title': 'Beau Is Afraid (2023)', 'genre': 'Comedy', 'director': 'Ari Aster', 'actor': ['Joaquin Phoenix']}
# {'title': 'Renfield (2023)', 'genre': 'Comedy', 'director': 'Chris McKay', 'actor': ['Nicolas Cage']}
# {'title': 'Love Again (2023)', 'genre': 'Comedy', 'director': 'Jim Strouse', 'actor': []}
# {'title': 'Fast X (2023)', 'genre': 'Action', 'director': 'Louis Leterrier', 'actor': ['Vin Diesel', 'Jason Momoa', 'Jason Statham', 'Brie Larson', 'Charlize Theron']}
# {'title': 'A Good Person (2023)', 'genre': 'Drama', 'director': 'Zach Braff', 'actor': ['Morgan Freeman']}
# {'title': 'Het geheugenspel (2023)', 'genre': 'Thriller', 'director': 'Lien Willaert', 'actor': []}
# {'title': 'The Little Mermaid (2023)', 'genre': 'Adventure', 'director': 'Rob Marshall', 'actor': ['Javier Bardem']}
# {'title': 'The Machine (2023)', 'genre': 'Action', 'director': 'Peter Atencio', 'actor': []}
# {'title': 'The Boogeyman (2023)', 'genre': 'Horror', 'director': 'Rob Savage', 'actor': []}
# {'title': 'Spider-Man: Across the Spider-Verse (2023)', 'genre': 'Animation', 'director': 'Joaquim Dos Santos', 'actor': ['Oscar Isaac']}
# {'title': 'Transformers: Rise of the Beasts (2023)', 'genre': 'Action', 'director': 'Steven Caple Jr.', 'actor': []}
# {'title': 'Strays (2023)', 'genre': 'Animation', 'director': 'Josh Greenbaum', 'actor': []}
# {'title': 'Spinning Gold (2023)', 'genre': 'Biography', 'director': 'Timothy Scott Bogart', 'actor': []}
# {'title': 'The Flash (2023)', 'genre': 'Action', 'director': 'Andy Muschietti', 'actor': ['Ben Affleck']}
# {'title': 'Elemental (2023)', 'genre': 'Animation', 'director': 'Peter Sohn', 'actor': []}
# {'title': 'About My Father (2023)', 'genre': 'Comedy', 'director': 'Laura Terruso', 'actor': ['Robert De Niro']}
# {'title': 'Extraction 2 (2023)', 'genre': 'Action', 'director': 'Sam Hargrave', 'actor': ['Chris Hemsworth', 'Olga Kurylenko', 'Golshifteh Farahani']}
# {'title': 'Asteroid City (2023)', 'genre': 'Comedy', 'director': 'Wes Anderson', 'actor': ['Scarlett Johansson', 'Tom Hanks', 'Bryan Cranston', 'Edward Norton', 'Margot Robbie']}
# {'title': 'No Hard Feelings (2023)', 'genre': 'Comedy', 'director': 'Gene Stupnitsky', 'actor': ['Jennifer Lawrence']}
# {'title': 'Indiana Jones and the Dial of Destiny (2023)', 'genre': 'Action', 'director': 'James Mangold', 'actor': ['Harrison Ford', 'Mads Mikkelsen']}
# {'title': 'Ruby Gillman, Teenage Kraken (2023)', 'genre': 'Animation', 'director': 'Kirk DeMicco', 'actor': []}
# {'title': 'Harold and the Purple Crayon (2023)', 'genre': 'Animation', 'director': 'Carlos Saldanha', 'actor': []}
# {'title': 'Insidious: The Red Door (2023)', 'genre': 'Horror', 'director': 'Patrick Wilson', 'actor': []}
# {'title': 'Mission: Impossible - Dead Reckoning Part One (2023)', 'genre': 'Action', 'director': 'Christopher McQuarrie', 'actor': ['Vanessa Kirby', 'Rebecca Ferguson', 'Tom Cruise']}
# {'title': 'Barbie (2023)', 'genre': 'Adventure', 'director': 'Greta Gerwig', 'actor': ['Margot Robbie', 'Ryan Gosling', 'Emma Mackey']}
# {'title': 'Oppenheimer (2023)', 'genre': 'Biography', 'director': 'Christopher Nolan', 'actor': ['Cillian Murphy', 'Emily Blunt', 'Matt Damon', 'Robert Downey Jr.', 'Gary Oldman', 'Rami Malek', 'Kenneth Branagh', 'Dane DeHaan']}
# {'title': 'Coyote v. Acme (2023)', 'genre': 'Animation', 'director': 'Dave Green', 'actor': []}
# {'title': 'They Cloned Tyrone (2023)', 'genre': 'Comedy', 'director': 'Juel Taylor', 'actor': []}
# {'title': 'How to Blow Up a Pipeline (2022)', 'genre': 'Crime', 'director': 'Daniel Goldhaber', 'actor': []}
# {'title': 'Haunted Mansion (2023)', 'genre': 'Comedy', 'director': 'Justin Simien', 'actor': ['Winona Ryder', 'Jared Leto']}
# {'title': 'Meg 2: The Trench (2023)', 'genre': 'Action', 'director': 'Ben Wheatley', 'actor': ['Jason Statham']}
# {'title': 'Teenage Mutant Ninja Turtles: Mutant Mayhem (2023)', 'genre': 'Animation', 'director': 'Jeff Rowe', 'actor': ['Jackie Chan']}
# {'title': 'Gran Turismo (2023)', 'genre': 'Action', 'director': 'Neill Blomkamp', 'actor': []}
# {'title': 'Blue Beetle (2023)', 'genre': 'Action', 'director': 'Angel Manuel Soto', 'actor': []}
# {'title': 'The Equalizer 3 (2023)', 'genre': 'Action', 'director': 'Antoine Fuqua', 'actor': ['Denzel Washington']}
# {'title': 'My Big Fat Greek Wedding 3 (2023)', 'genre': 'Comedy', 'director': 'Nia Vardalos', 'actor': []}
# {'title': 'Expend4bles (2023)', 'genre': 'Action', 'director': 'Scott Waugh', 'actor': ['Jason Statham', 'Sylvester Stallone']}
# {'title': 'Wil (2023)', 'genre': 'Drama', 'director': 'Tim Mielants', 'actor': []}
# {'title': 'Kraven the Hunter (2023)', 'genre': 'Action', 'director': 'J.C. Chandor', 'actor': ['Russell Crowe']}
# {'title': 'Spray (2023)', 'genre': 'Action', 'director': 'Meg Leonard', 'actor': []}
# {'title': 'PAW Patrol: The Mighty Movie (2023)', 'genre': 'Animation', 'director': 'Cal Brunker', 'actor': []}
# {'title': 'Herseye Ragmen (2022)', 'genre': 'Drama', 'director': 'Erdal Murat Aktas', 'actor': []}
# {'title': 'Trolls Band Together (2023)', 'genre': 'Animation', 'director': 'Walt Dohrn', 'actor': ['Anna Kendrick']}
# {'title': 'Saw X (2023)', 'genre': 'Horror', 'director': 'Kevin Greutert', 'actor': []}
# {'title': 'Dune: Part Two (2023)', 'genre': 'Action', 'director': 'Denis Villeneuve', 'actor': ['Rebecca Ferguson', 'Timothée Chalamet', 'Zendaya', 'Léa Seydoux', 'Josh Brolin', 'Javier Bardem']}
# {'title': 'The Hunger Games: The Ballad of Songbirds and Snakes (2023)', 'genre': 'Action', 'director': 'Francis Lawrence', 'actor': []}
# {'title': 'Wish (2023)', 'genre': 'Animation', 'director': 'Chris Buck', 'actor': ['Chris Pine']}
# {'title': 'Migration (2023)', 'genre': 'Animation', 'director': 'Benjamin Renner', 'actor': []}
# {'title': 'Wonka (2023)', 'genre': 'Adventure', 'director': 'Paul King', 'actor': ['Timothée Chalamet']}
# {'title': "J'aime la vie (2023)", 'genre': 'Drama', 'director': 'Mathias Sercu', 'actor': []}
# {'title': 'Aquaman and the Lost Kingdom (2023)', 'genre': 'Action', 'director': 'James Wan', 'actor': ['Jason Momoa', 'Ben Affleck', 'Nicole Kidman', 'Amber Heard']}
# {'title': 'Ghostbusters Sequel (2023)', 'genre': 'Adventure', 'director': 'Gil Kenan', 'actor': []}
# {'title': 'Night Swim (2024)', 'genre': 'Horror', 'director': 'Bryce McGuire', 'actor': []}

# %% [markdown]
# # Test du scraping allociné

# %%
for page in range(1, 21):
    url_actor_star = f'https://www.allocine.fr/personne/top/les-plus-vues/ever/?page={page}'
    #le f sert à formater l'URL
    response_actor = requests.get(url_actor_star)
    actor_soup = BeautifulSoup(response_actor.content, 'html.parser')
    list_actors = actor_soup.find_all('a', class_= "meta-title-link")
    
    for actor in list_actors:
        actor_star = actor.text.strip()

        print(actor_star)
# Out:
# Leonardo DiCaprio
# Quentin Tarantino
# Clint Eastwood
# Will Smith
# Brad Pitt
# Tom Cruise
# Margot Robbie
# Jason Statham
# Omar Sy
# Johnny Depp
# Christopher Nolan
# Tom Hardy
# Dwayne Johnson
# Xavier Dolan
# Denzel Washington
# Tom Hanks
# Steven Spielberg
# Jake Gyllenhaal
# Virginie Efira
# Bruce Willis
# Jean Dujardin
# Ryan Gosling
# Guillaume Canet
# François Civil
# Vincent Cassel
# Matt Damon
# Pierre Niney
# Scarlett Johansson
# Tim Burton
# Joaquin Phoenix
# Jennifer Lawrence
# Sylvester Stallone
# Robert De Niro
# Liam Neeson
# Camille Lellouche
# Gérard Depardieu
# Nicolas Cage
# Gal Gadot
# Cillian Murphy
# Marion Cotillard
# Denis Villeneuve
# Tom Holland
# Ben Affleck
# Emilia Clarke
# Albert Dupontel
# Ryan Reynolds
# Matthew McConaughey
# Emma Watson
# Emma Stone
# Jim Carrey
# Christian Clavier
# Christian Bale
# Keanu Reeves
# Louis de Funès
# Anya Taylor-Joy
# Alicia Vikander
# Philippe Lacheau
# James McAvoy
# Bradley Cooper
# Timothée Chalamet
# Henry Cavill
# Chloë Grace Moretz
# Woody Allen
# Millie Bobby Brown
# Camille Cottin
# Mel Gibson
# Martin Scorsese
# Élodie Fontan
# Ana de Armas
# Hayao Miyazaki
# Samuel L. Jackson
# Chris Hemsworth
# Jessica Chastain
# Charlie Hunnam
# Dany Boon
# Charlize Theron
# Gilles Lellouche
# Pedro Almodóvar
# Eddie Redmayne
# Jean-Pierre Bacri
# Natalie Portman
# David Fincher
# Morgan Freeman
# Rami Malek
# Adam Driver
# Emily Blunt
# Eva Green
# Manon Azem
# Benoît Poelvoorde
# Mark Wahlberg
# Michael Fassbender
# Vin Diesel
# M. Night Shyamalan
# Romain Duris
# Jean-Claude Van Damme
# Robert Downey Jr.
# Mélanie Laurent
# Viggo Mortensen
# Jackie Chan
# Rebecca Ferguson
# Adèle Exarchopoulos
# Gerard Butler
# Benedict Cumberbatch
# Luc Besson
# Anthony Hopkins
# Brie Larson
# Audrey Fleurot
# Anne Hathaway
# Zac Efron
# Jean-Paul Belmondo
# Daniel Craig
# Keira Knightley
# Daniel Auteuil
# Isabelle Huppert
# Gaspard Ulliel
# Ridley Scott
# Hugh Jackman
# Jean Reno
# Leïla Bekhti
# Felicity Jones
# Jason Momoa
# Arnold Schwarzenegger
# Rosamund Pike
# Nicole Kidman
# Guy Ritchie
# Chris Pratt
# Pio Marmaï
# Julia Roberts
# Quentin Dupieux
# Victor Meutelet
# Kristen Stewart
# Wes Anderson
# Amy Adams
# Travis Fimmel
# Harrison Ford
# Daniel Radcliffe
# Kevin Costner
# Chris Evans
# Franck Dubosc
# Kate Winslet
# Franck Gastambide
# Zoe Saldana
# Morena Baccarin
# Cara Delevingne
# Léa Seydoux
# Michael B. Jordan
# Benoît Magimel
# Cate Blanchett
# Noomi Rapace
# Shailene Woodley
# Mads Mikkelsen
# Kev Adams
# François Damiens
# Jeffrey Dean Morgan
# Dylan O'Brien
# Alice Isaaz
# Rachel McAdams
# Bong Joon Ho
# Cécile de France
# Jamie Dornan
# Alexandra Daddario
# Angelina Jolie
# Daisy Ridley
# Julia Piaton
# Sophie Marceau
# Fabrice Luchini
# James Franco
# Catherine Deneuve
# Vincent Lacoste
# Russell Crowe
# Jonathan Cohen
# Woody Harrelson
# Kaya Scodelario
# Rayane Bensetti
# François Cluzet
# Karin Viard
# Thomas Brodie-Sangster
# Kad Merad
# Jared Leto
# Idris Elba
# Marina Foïs
# Olivier Marchal
# Ken Loach
# Al Pacino
# Alexandra Lamy
# Taron Egerton
# George Clooney
# Freddie Highmore
# Guillermo del Toro
# Adèle Haenel
# Dakota Johnson
# Robert Pattinson
# Channing Tatum
# Colin Farrell
# Jennifer Connelly
# Edward Norton
# François Ozon
# James Cameron
# Jean-Paul Rouve
# Lily James
# Blake Lively
# Bryce Dallas Howard
# Luke Evans
# Ana Girardot
# Juliette Binoche
# Zendaya
# Sabrina Ouazani
# Jude Law
# Oscar Isaac
# Katheryn Winnick
# Alain Chabat
# Úrsula Corberó
# Karen Gillan
# Sandra Bullock
# Sofia Boutella
# Meryl Streep
# Penélope Cruz
# Amber Heard
# Bryan Cranston
# Laure Calamy
# Mahershala Ali
# Laurence Arné
# Reda Kateb
# Cédric Klapisch
# Robin Williams
# Josiane Balasko
# Elle Fanning
# Matthias Schoenaerts
# Winona Ryder
# Josh Brolin
# Alexander Skarsgård
# Laurent Lafitte
# Pedro Pascal
# Damien Chazelle
# Anaïs Demoustier
# Ewan McGregor
# Javier Bardem
# Ramzy Bedia
# Chris Pine
# Sam Claflin
# Kenneth Branagh
# José Garcia
# Alice Belaïdi
# Charlotte Gainsbourg
# Louis Garrel
# Emma Mackey
# Golshifteh Farahani
# Pierre Richard
# Richard Madden
# Mathieu Kassovitz
# Elliot Page
# Vincent Lindon
# David Lynch
# Helena Bonham Carter
# Julie de Bona
# Olga Kurylenko
# Tessa Thompson
# Elizabeth Olsen
# Stanley Kubrick
# Ethan Hawke
# Colin Firth
# Noémie Schmidt
# Anna Kendrick
# Roschdy Zem
# Patrick Bruel
# Dane DeHaan
# Andrew Garfield
# Clémence Poésy
# Thierry Lhermitte
# Christoph Waltz
# Sandrine Kiberlain
# Scott Eastwood
# Jeremy Renner
# Tahar Rahim
# Lambert Wilson
# Bill Skarsgård
# Sam Worthington
# Alban Ivanov
# Emma Thompson
# Nicolas Duvauchelle
# Gary Oldman
# Reem Kherici
# Kurt Russell
# Jacques Audiard
# Vanessa Kirby
# Sophie Turner
# Alejandro González Iñárritu
# Kevin Hart
# Tom Hiddleston
# Naomi Watts
# Chadwick Boseman
# Hatik
# Sean Connery
# Elisabeth Moss
# Jack Nicholson
# Ralph Fiennes
# Theo James
# Miles Teller
# Maïwenn
# John Travolta
